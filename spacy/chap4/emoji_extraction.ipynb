# %%
import spacy
from spacy.matcher import Matcher

nlp = spacy.load('en_core_web_md')
# Out:
# 2022-04-14 13:56:43.975458: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nicolas/openssl/lib
# 2022-04-14 13:56:43.975487: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
pos_emoji = ['😀', '😃', '😂', '😊', '😁', '😍']

# %%
neg_emoji = ['😔', '😠', '😩', '😢', '😭', '😒']

# %%
pos_patterns = [[{'ORTH': emoji}] for emoji in pos_emoji]

# %%
neg_patterns = [[{'ORTH': emoji} for emoji in neg_emoji]]

# %%
matcher = Matcher(nlp.vocab)

# %%
matcher.add('posEmoji', pos_patterns)

# %%
matcher.add('nedEmoji', neg_patterns)

# %%
doc = nlp('I love Zara 😍')

# %%
for mid, start, end in matcher(doc):
    print(start, end, doc[start:end])
# Out:
# 3 4 😍
